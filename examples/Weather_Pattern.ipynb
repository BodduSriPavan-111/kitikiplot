# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from kitikiplot import KitikiPlot
import pandas as pd

os.chdir("..")

# %%
df= pd.read_csv( "datasets/weatherHistory/weatherHistory.csv")
print("Shape: ", df.shape)
df= df.iloc[45:65, :]
print("Shape: ", df.shape)
df.head(3)
# Out:
# Shape:  (96453, 12)
# Shape:  (20, 12)
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 45  2006-04-10 21:00:00.000 +0200  Mostly Cloudy        rain        15.022222
# 46  2006-04-10 22:00:00.000 +0200       Overcast        rain        14.422222
# 47  2006-04-10 23:00:00.000 +0200       Overcast        rain        14.255556
#
#     Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 45                 15.022222      0.55            21.3808
# 46                 14.422222      0.58            20.0123
# 47                 14.255556      0.59            16.5025
#
#     Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 45                   159.0           9.9820         0.0               1008.15
# 46                   159.0          15.8263         0.0               1007.85
# 47                   168.0          14.9569         0.0               1007.89
#
#                         Daily Summary
# 45  Mostly cloudy throughout the day.
# 46  Mostly cloudy throughout the day.
# 47  Mostly cloudy throughout the day.

# %%
index= 0

ktk= KitikiPlot( data= df["Summary"].values.tolist(), stride= 1, window_length= 10 )

ktk.plot(
        figsize= (20, 5),
        cell_width= 2,
        transpose= True,
        ytick_prefix= "Window",
        xlabel= "Time",
        ylabel= "Windows",
        xticks_values= [(str(i.hour)+" "+i.strftime("%p").lower()) for i in  pd.to_datetime(df["Formatted Date"])],
        xticks_rotation= 90, 
        cmap= {"Mostly Cloudy": "brown", "Partly Cloudy": "#a9cbe0","Overcast": "#fdbf6f"},
        legend_kwargs= {"bbox_to_anchor": (1.01, 1), "loc":'upper left', "borderaxespad": 0.},
        display_legend= True,
        title= "Weather Pattern on "+str( pd.to_datetime( df.iloc[0, 0] ).date()))

# %%
index= 0

ktk= KitikiPlot( data= df["Summary"].values.tolist(), stride= 1, window_length= 10 )

ktk.plot(
        figsize= (20, 5),
        cell_width= 2,
        transpose= False,
        xlabel= "Whindow",
        ylabel= "Time",
        yticks_values= [(str(i.hour)+" "+i.strftime("%p").lower()) for i in  pd.to_datetime(df["Formatted Date"])],
        xticks_rotation= 90, 
        cmap= {"Mostly Cloudy": "brown", "Partly Cloudy": "#a9cbe0","Overcast": "#fdbf6f"},
        legend_kwargs= {"bbox_to_anchor": (1.01, 1), "loc":'upper left', "borderaxespad": 0.},
        display_legend= True,
        title= "Weather Pattern on "+str( pd.to_datetime( df.iloc[0, 0] ).date()))
