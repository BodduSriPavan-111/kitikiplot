# %%
import sys
import os

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from kitikiplot import kitikiplot
import pandas as pd

# %%
df= pd.read_csv( r"C:\Users\sinch\Desktop\Sliding_Window\fish_120.csv" )

# %%
plot= kitikiplot( data= df )

# %%
plot.plot()

# %%
import pandas as pd
import matplotlib

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
matplotlib.__version__
# Out:
# '3.9.0'
