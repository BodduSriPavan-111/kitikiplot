# %% [markdown]
# ## KitikiPlot: Slide the window !
# KitikiPlot is a Python library for visualizing sequential and time-series categorical "Sliding Window" data.
# (The term 'kitiki' means 'window' in Telugu)

# %% [markdown]
# ##### Import necessary libraries

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from kitikiplot.core import KitikiPlot
import pandas as pd

os.chdir("..")

# %% [markdown]
# ##### Initialize with a list of sequential data
# Dataset contains the weather details collected at consecutive time intervals. <br>
# URL: https://www.kaggle.com/datasets/muthuj7/weather-dataset

# %%
df= pd.read_csv( "datasets/weatherHistory/weatherHistory.csv")
print("Shape: ", df.shape)
df= df.iloc[45:65, :]
print("Shape: ", df.shape)
df.head(3)
# Out:
# Shape:  (96453, 12)
# Shape:  (20, 12)
#                    Formatted Date        Summary Precip Type  Temperature (C)  \
# 45  2006-04-10 21:00:00.000 +0200  Mostly Cloudy        rain        15.022222
# 46  2006-04-10 22:00:00.000 +0200       Overcast        rain        14.422222
# 47  2006-04-10 23:00:00.000 +0200       Overcast        rain        14.255556
#
#     Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 45                 15.022222      0.55            21.3808
# 46                 14.422222      0.58            20.0123
# 47                 14.255556      0.59            16.5025
#
#     Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 45                   159.0           9.9820         0.0               1008.15
# 46                   159.0          15.8263         0.0               1007.85
# 47                   168.0          14.9569         0.0               1007.89
#
#                         Daily Summary
# ...

# %%
df["Summary"].values.tolist()
# Out:
# ['Mostly Cloudy',
#  'Overcast',
#  'Overcast',
#  'Overcast',
#  'Overcast',
#  'Overcast',
#  'Overcast',
#  'Overcast',
#  'Overcast',
#  'Mostly Cloudy',
#  'Mostly Cloudy',
#  'Partly Cloudy',
#  'Partly Cloudy',
#  'Partly Cloudy',
#  'Partly Cloudy',
#  'Mostly Cloudy',
#  'Mostly Cloudy',
#  'Mostly Cloudy',
#  'Mostly Cloudy',
#  'Mostly Cloudy']

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( )     # No legend is displayed by default

# %% [markdown]
# ##### Adjust the stride of sliding window using <font color="steelblue"><b><i>'stride'<i/></b></font>
# stride : int (optional) <br>
# - The number of elements to move the window after each iteration when converting a list to a DataFrame. <br>
# - Default is 1.

# %%
index= 0

ktk= KitikiPlot( data= df["Summary"].values.tolist(), stride= 2 )

ktk.plot( cell_width= 2, transpose= True )

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist(), stride= 5 )

ktk.plot( cell_width= 2, transpose= True )
# Out:
# Total Data:  ['Mostly Cloudy' 'Overcast' 'Overcast' 'Overcast' 'Overcast' 'Overcast'
#  'Overcast' 'Overcast' 'Overcast' 'Mostly Cloudy' 'Mostly Cloudy'
#  'Partly Cloudy' 'Partly Cloudy' 'Partly Cloudy' 'Partly Cloudy'
#  'Mostly Cloudy' 'Mostly Cloudy' 'Mostly Cloudy' 'Mostly Cloudy'
#  'Mostly Cloudy']
# Window Range:  range(0, 3)
# COlumns Range:  10
# Each sample length:  20

# %% [markdown]
# ##### Adjust the length of sliding window using <font color="steelblue"><b><i>'window_length'<i/></b></font>
# window_length : int (optional) <br>
# - The length of each window when converting a list to a DataFrame. <br>
# - Default is 10.

# %%
index= 0

ktk= KitikiPlot( data= df["Summary"].values.tolist(), window_length= 5 )

ktk.plot( transpose= True,
          xtick_prefix= "Frame",
          ytick_prefix= "Window",
          cell_width= 2 )

# %%
index= 0

ktk= KitikiPlot( data= df["Summary"].values.tolist(), window_length= 10 )

ktk.plot( transpose= True,
          xtick_prefix= "Frame",
          ytick_prefix= "Window",
          cell_width= 2 )
# Out:
# Total Data:  ['Mostly Cloudy' 'Overcast' 'Overcast' 'Overcast' 'Overcast' 'Overcast'
#  'Overcast' 'Overcast' 'Overcast' 'Mostly Cloudy' 'Mostly Cloudy'
#  'Partly Cloudy' 'Partly Cloudy' 'Partly Cloudy' 'Partly Cloudy'
#  'Mostly Cloudy' 'Mostly Cloudy' 'Mostly Cloudy' 'Mostly Cloudy'
#  'Mostly Cloudy']
# Window Range:  range(0, 11)
# COlumns Range:  10
# Each sample length:  20

# %% [markdown]
# ##### Adjust size of the plot using <font color="steelblue"><b><i>'figsize'<i/></b></font>
# figsize : tuple (optional)<br>
# - The size of the figure (width, height).<br>
# - Default is (25, 5).

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( figsize= (20, 8) )

# %% [markdown]
# ##### Adjust cell width using <font color="steelblue"><b><i>'cell_width'<i/></b></font>
# cell_width : float <br>
# - The width of each cell in the grid. <br>
# - Default is 0.5.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( cell_width= 2 )

# %% [markdown]
# ##### Adjust cell height using <font color="steelblue"><b><i>'cell_height'<i/></b></font>
# cell_height : float <br>
# - The height of each cell in the grid. <br>
# - Default is 2.0.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( cell_height= 3 )

# %% [markdown]
# ##### Focus plotting using <font color="steelblue"><b><i>'focus'<i/></b></font>
# focus : tuple or list or None (optional) <br>
# - Index range to set focus/ highlight <br>
# - If focus is (i, j) then index values: i, i+1, i+2, ... j-1 are highlighted (0% transparent) </br>
# - Default is None.

# %%
CO_values= [3, 3, 3, 3, -200, 2, 1, 1, 1, 1, 2, 3, 4, 4, 3, 3, 3, 2]
time_period= ['0 am', '1 am', '2 am', '3 am', '4 am', '5 am', '6 am', '7 am', '8 am', '9 am', '10 am',
              '11 am', '12 pm', '13 pm', '14 pm', '15 pm', '16 pm', '17 pm']
ktk= KitikiPlot( data= CO_values, stride= 1, window_length= 8 )

ktk.plot(
        figsize= (20, 5),
        cell_width= 2,
        cmap= {-200: "#00db3e", 1: "#00b7db", 2: "#4400d8", 3: "#ff7070", 4: "#b0009b"},
        focus= True,
        transpose= False,
        xlabel= "Sliding Windows of CO(GT) values (in mg/m^3)",
        ylabel= "Time",
        display_xticks= True,
        yticks_values= time_period,
        ytick_prefix= "Window",
        xticks_rotation= 90, 
        display_legend= True,
        title= "CO(GT) Trend in Air",
        legend_kwargs= {"bbox_to_anchor": (1.01, 1), "loc":'upper left', "borderaxespad": 0.})

# %% [markdown]
# ##### Adjust focus color transparency using <font color="steelblue"><b><i>'focus_alpha'<i/></b></font>
# focus_alpha : float (optional) <br>
# - Transparency value to de-emphasize indices falling out of 'focus'. <br>
# - Default is 0.25.

# %%
CO_values= [3, 3, 3, 3, -200, 2, 1, 1, 1, 1, 2, 3, 4, 4, 3, 3, 3, 2]
time_period= ['0 am', '1 am', '2 am', '3 am', '4 am', '5 am', '6 am', '7 am', '8 am', '9 am', '10 am',
              '11 am', '12 pm', '13 pm', '14 pm', '15 pm', '16 pm', '17 pm']
ktk= KitikiPlot( data= CO_values, stride= 1, window_length= 8 )

ktk.plot(
        figsize= (20, 5),
        cell_width= 2,
        cmap= {-200: "#00db3e", 1: "#00b7db", 2: "#4400d8", 3: "#ff7070", 4: "#b0009b"},
        focus= True,
        focus_alpha= 0.05,
        transpose= False,
        xlabel= "Sliding Windows of CO(GT) values (in mg/m^3)",
        ylabel= "Time",
        display_xticks= True,
        yticks_values= time_period,
        ytick_prefix= "Window",
        xticks_rotation= 90, 
        display_legend= True,
        title= "CO(GT) Trend in Air",
        legend_kwargs= {"bbox_to_anchor": (1.01, 1), "loc":'upper left', "borderaxespad": 0.})

# %% [markdown]
# ##### Transpose the plot using <font color="steelblue"><b><i>'transpose'<i/></b></font>
# transpose : bool (optional) <br>
# - A flag indicating whether to transpose the KitikiPlot. <br>
# - Default is False.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( transpose= False )

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( 
            cell_width= 2,
            transpose= True,
            xtick_prefix= "Frame",
            ytick_prefix= "Window",
            xlabel= "Frames",
            ylabel= "Sliding_Windows" )

# %% [markdown]
# ##### Adjust window gap using <font color="steelblue"><b><i>'window_gap'<i/></b></font>
# window_gap : float <br>
# - The gap between cells in the grid. <br>
# - Default is 1.0.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( window_gap= 3 )

# %% [markdown]
# ##### Adjust window range using <font color="steelblue"><b><i>'window_range'<i/></b></font>
# window_range : str or tuple (optional) <br>
# - The range of windows to display. <br>
# - Use "all" to show all windows or specify a tuple (start_index, end_index). <br>
# - Default is "all".

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( window_range= "all" )

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( window_range= (3,8) )

# %% [markdown]
# ##### Adjust cells alignment using <font color="steelblue"><b><i>'align'<i/></b></font>
# align : bool <br>
# - A flag indicating whether to shift consecutive bars vertically (if transpose= False), and <br>
#   horizontally(if transpose= True) by stride value. <br>
# - Default is True.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( align= True )

# %%
ktk.plot( 
         align= False,
         display_yticks= False # Display no yticks
        )

# %%
ktk.plot( 
         cell_width= 2, 
         align= True, 
         transpose= True, 
         xlabel= "Frames",
         ylabel= "Sliding Windows",
         xtick_prefix= "Frame",
         ytick_prefix= "Window"
        )

# %%
ktk.plot( 
         cell_width= 2, 
         align= False, 
         transpose= True,
         xlabel= "Frames",
         ylabel= "Sliding Windows",
         ytick_prefix= "Window",
         display_xticks= False 
        )

# %% [markdown]
# ##### Adjust color map using <font color="steelblue"><b><i>'cmap'<i/></b></font>
# cmap : str or dict <br>
# - If a string, it should be a colormap name to generate colors. <br>
# - If a dictionary, it should map unique values to specific colors. <br>
# - Default is 'rainbow'.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( 
          cmap= "Greens",
          display_legend= True
        )

# %%
ktk.plot( 
          cmap= {"Mostly Cloudy": "Green"},
          display_legend= True
        )

# %% [markdown]
# ##### Adjust fallback color using <font color="steelblue"><b><i>'fallback_color'<i/></b></font>
# fallback_color : str <br>
# - The color to use as fallback if no specific color is assigned. <br>
# - Default is '#FAFAFA'.

# %%
ktk.plot( 
          cmap= {"Mostly Cloudy": "Green"},
          fallback_color= "wheat",
          display_legend= True
        )

# %% [markdown]
# ##### Adjust edge color using <font color="steelblue"><b><i>'edge_color'<i/></b></font>
# edge_color : str <br>
# - The color to use for the edges of the rectangle. <br>
# - Default is '#000000'.

# %%
ktk.plot( 
          cmap= {"Mostly Cloudy": "Green"},
          fallback_color= "wheat",
          edge_color= "blue",
        )

# %% [markdown]
# ##### Display hatch using <font color="steelblue"><b><i>'display_hatch'<i/></b></font>
# display_hatch : bool <br>
# - A flag indicating whether to display hatch patterns on cells. <br>
# - Default is False.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( 
          cmap= {"Mostly Cloudy": "#ffffff"},
          fallback_color= "white",
          display_hatch= True
        )

# %% [markdown]
# ##### Customize hatch using <font color="steelblue"><b><i>'hmap'<i/></b></font>
# hmap : dict <br>
# - A dictionary mapping unique values to their corresponding hatch patterns. <br>
# - Default is '{}'.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( 
          cmap= {"Mostly Cloudy": "grey"},
          fallback_color= "white",
          hmap= {"Mostly Cloudy": "|*|"},
          display_hatch= True
        )

# %% [markdown]
# ##### Customize fallback hatch using <font color="steelblue"><b><i>'fallback_hatch'<i/></b></font>
# fallback_hatch : str <br>
# - The hatch pattern to use as fallback if no specific hatch is assigned. <br>
# - Default is '" "' (string with single space).

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( 
          cmap= {"Mostly Cloudy": "grey"},
          fallback_color= "white",
          hmap= {"Mostly Cloudy": "|*|"},
          fallback_hatch= "\\",
          display_hatch= True
        )

# %% [markdown]
# ##### Add legend to the plot using <font color="steelblue"><b><i>'display_legend= True'<i/></b></font>
# display_legend : bool (optional)<br>
# - A flag indicating whether to display a legend on the plot.<br>
# - Default is False.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( display_legend= True )

# %% [markdown]
# ##### Add hatch to legend using <font color="steelblue"><b><i>'legend_hatch'<i/></b></font>
# legend_hatch : bool (optional) <br>
# - A flag indicating whether to include hatch patterns in the legend. <br>
# - Default is False.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( 
          cmap= {"Mostly Cloudy": "#ffffff"},
          fallback_color= "white",
          display_hatch= True,
          display_legend= True,
          legend_hatch= True
        )

# %% [markdown]
# ##### Customize xlabel using <font color="steelblue"><b><i>'xlabel'<i/></b></font>
# xlabel : str (optional)<br>
# - Label for the x-axis.<br>
# - Default is "Sliding Windows".

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( xlabel= "Observation Window" )

# %% [markdown]
# ##### Customize ylabel using <font color="steelblue"><b><i>'ylabel'<i/></b></font>
# ylabel : str (optional)<br>
# - Label for the y-axis.<br>
# - Default is "Frames".

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( ylabel= "Frame ID" )

# %% [markdown]
# ##### Display xticks and values using <font color="steelblue"><b><i>'display_xticks'<i/></b></font>
# display_xticks : bool (optional)<br>
# - A flag indicating whether to display xticks<br>
# - Default is True

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( display_xticks= False )

# %% [markdown]
# ##### Display yticks and values using <font color="steelblue"><b><i>'display_yticks'<i/></b></font>
# display_yticks : bool (optional)<br>
# - A flag indicating whether to display yticks<br>
# - Default is True

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( display_yticks= False )

# %% [markdown]
# ##### Customize xtick prefix using <font color="steelblue"><b><i>'xtick_prefix'<i/></b></font>
# xtick_prefix : str (optional)<br>
# - Prefix for x-axis tick labels.<br>
# - Default is "Window".

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( xtick_prefix= "Observation" )

# %% [markdown]
# ##### Customize ytick prefix using <font color="steelblue"><b><i>'ytick_prefix'<i/></b></font>
# ytick_prefix : str (optional)<br>
# - Prefix for y-axis tick labels.<br>
# - Default is "Frame".

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( ytick_prefix= "Time" )

# %% [markdown]
# ##### Customize xticks values using <font color="steelblue"><b><i>'xticks_values'<i/></b></font>
# xticks_values : list (optional) <br>
# - List containing the values for xticks <br>
# - Default is []

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

xtick_values= ['Start', "T1", "T2", "T3", "T4", "T5", "T6", "T7", "T8", "T9", "End"]
ktk.plot( xticks_values= xtick_values )

# %% [markdown]
# ##### Customize yticks values using <font color="steelblue"><b><i>'yticks_values'<i/></b></font>
# yticks_values : list (optional) <br>
# - List containing the values for yticks <br>
# - Default is []

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

yticks_values= [(str(i.hour)+" "+i.strftime("%p").lower()) for i in  pd.to_datetime(df["Formatted Date"])]
ktk.plot( yticks_values= yticks_values )

# %% [markdown]
# ##### Customize rotation of xticks and values using<font color="steelblue"><b><i>'xticks_rotation'<i/></b></font>
# xticks_rotation : int (optional) <br>
# - Rotation angle for x-axis tick labels. <br>
# - Default is 0.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( xticks_rotation= 45 )

# %% [markdown]
# ##### Customize rotation of yticks and values using<font color="steelblue"><b><i>'yticks_rotation'<i/></b></font>
# yticks_rotation : int (optional) <br>
# - Rotation angle for y-axis tick labels. <br>
# - Default is 0.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( figsize= (20, 8),     # Increase height of the plot for good visualization (here)
          yticks_rotation= 45 
        )

# %% [markdown]
# ##### Set the title using <font color="steelblue"><b><i>'title'<i/></b></font>
# title : str (optional) <br>
# - The title of the plot. <br>
# - Default is "KitikiPlot: Intuitive Visualization for Sliding Window".

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist() )

ktk.plot( title= "KitikiPlot for Weather Dataset")

# %% [markdown]
# ##### Display grid using <font color="steelblue"><b><i>'display_grid'<i/></b></font>
# display_grid : bool (optional) <br>
# - A flag indicating whether to display grid on the plot. <br>
# - Default is False.

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist()[:15] )

ktk.plot( display_grid= True )

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist()[:15] )

ktk.plot( 
          cell_width= 2,
          transpose= True,  
          xlabel= "Frames",
          ylabel= "Sliding Windows",
          ytick_prefix= "Window",
          display_xticks= False,
          display_grid= True 
        )

# %% [markdown]
# ##### Customize legend using <font color="steelblue"><b><i>'return_figure'<i/></b></font>
# return_figure : bool (optional) <br>
# - A flag indicating whether to return plot. <br>
# - Default is False. <br>

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist(), stride= 5 )

figure= ktk.plot( cell_width= 2, transpose= True, return_figure= True ) 

figure.show()
# Out:
# Total Data:  ['Mostly Cloudy' 'Overcast' 'Overcast' 'Overcast' 'Overcast' 'Overcast'
#  'Overcast' 'Overcast' 'Overcast' 'Mostly Cloudy' 'Mostly Cloudy'
#  'Partly Cloudy' 'Partly Cloudy' 'Partly Cloudy' 'Partly Cloudy'
#  'Mostly Cloudy' 'Mostly Cloudy' 'Mostly Cloudy' 'Mostly Cloudy'
#  'Mostly Cloudy']
# Window Range:  range(0, 3)
# COlumns Range:  10
# Each sample length:  20
# C:\Users\bsnra\AppData\Local\Temp\ipykernel_23524\1808831343.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   figure.show()

# %% [markdown]
# ##### Customize legend using <font color="steelblue"><b><i>'legend_kwargs'<i/></b></font>
# legend_kwargs : dict (optional) <br>
# - Additional keyword arguments passed to customize the legend. <br>
# - Default is {}. <br>

# %% [markdown]
# Place legend outside of the Plot

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist()[:15] )

ktk.plot( 
        figsize= (15, 5),
        display_legend= True,
        legend_kwargs= {"bbox_to_anchor": (1, 1.0), "loc":"upper left"} )

# %% [markdown]
# Set title for the legend

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist()[:15] )

ktk.plot( 
          figsize= (15, 5),
          display_legend= True,
          legend_kwargs= {"title": "Weather Conditions"} 
        )

# %% [markdown]
# Change edgecolor of the legend

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist()[:15] )

ktk.plot( 
          figsize= (15, 5),
          display_legend= True,
          legend_kwargs= {"edgecolor": "lime"} 
        )

# %% [markdown]
# ##### Customize kitiki_cell (rectangular cell) using <font color="steelblue"><b><i>'kitiki_cell_kwargs'<i/></b></font>
# kitiki_cell_kwargs : dict (optional) <br>
# - Additional keyword arguments passed to customize individual cells. <br>
# - Default is {}.

# %% [markdown]
# Set the line style

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist()[:15] )

ktk.plot( 
        figsize= (15, 5),
        kitiki_cell_kwargs= {"linestyle": "--"} )

# %% [markdown]
# Adjust the line width

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist()[:15] )

ktk.plot( 
        figsize= (15, 5),
        kitiki_cell_kwargs= {"linewidth": 3} )

# %% [markdown]
# Adjust the alpha

# %%
ktk= KitikiPlot( data= df["Summary"].values.tolist()[:15] )

ktk.plot( 
        figsize= (15, 5),
        kitiki_cell_kwargs= {"alpha": 0.4} )

# %% [markdown]
# END
#
# _____________________________
