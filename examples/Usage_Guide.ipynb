# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from kitikiplot import kitikiplot
import pandas as pd

df= pd.read_csv( r"fish_10.csv" )

plot= kitikiplot( data= [i for i in "A T G C A A T T T T G G G G C C A ".split()], stride= 3 )
# Out:
# Inside list:  [['A', 'T', 'G', 'C', 'A', 'A', 'T', 'T', 'T', 'T'], ['C', 'A', 'A', 'T', 'T', 'T', 'T', 'G', 'G', 'G'], ['T', 'T', 'T', 'T', 'G', 'G', 'G', 'G', 'C', 'C'], ['T', 'G', 'G', 'G', 'G', 'C', 'C', 'A', 'No_Data', 'No_Data']]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches


a_val = 0.6
colors = ['#EA5739','#FEFFBE','#4BB05C']


circ1 = mpatches.Patch( facecolor=colors[0],alpha=a_val,hatch=r'---',label='Label1')
circ2= mpatches.Patch( facecolor=colors[1],alpha=a_val,hatch='o',label='Label2')
circ3 = mpatches.Patch(facecolor=colors[2],alpha=a_val,hatch='+',label='Label3')

fig,(ax) = plt.subplots()

ax.legend(handles = [circ1,circ2,circ3],loc=2)
plt.tight_layout()

# %%
plot.plot(figsize= (10, 5), cell_width= 3, display_legend= True, display_hatch= True, legend_hatch= True,
          kitiki_cell_kwargs= {"linestyle": "-"},
           legend_kwargs= {"bbox_to_anchor": (1.05, 1), "loc":'upper left', "borderaxespad": 0.},
            transpose= True,
             xticks_rotation= 90 )
# Out:
# Color COnfig beofre start:  ({'A': '#8000ff', 'T': '#00b4ec', 'G': '#80ffb4', 'C': '#ffb462', 'No_Data': '#ff0000'}, '#000000')
# ...
# _____________Legend Patches [<matplotlib.patches.Patch object at 0x0000020E2267C2D0>, <matplotlib.patches.Patch object at 0x0000020E228AC950>, <matplotlib.patches.Patch object at 0x0000020E22679810>, <matplotlib.patches.Patch object at 0x0000020E22679C50>, <matplotlib.patches.Patch object at 0x0000020E22692090>]
# _____________Hatch Map {'A': 'o', 'T': '/', 'G': '*', 'C': '\\', 'No_Data': '..'}
# _____________Legend Hatch True
# _____________Mapping:  ['o', '/', '*', '\\', '..']
# _________________ {'bbox_to_anchor': (1.05, 1), 'loc': 'upper left', 'borderaxespad': 0.0}
# _______ {'bbox_to_anchor': (1.05, 1), 'loc': 'upper left', 'borderaxespad': 0.0}

# %%
plot.plot(figsize= (10, 5), cmap= "rainbow", cell_width= 3, display_hatch= True )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot.plot(figsize= (10, 5), cmap= "rainbow", cell_width= 3, display_hatch= True )
#
# NameError: name 'plot' is not defined

# %%
legend_dict
# Out:
# {'ncol': 1, 'loc': 'best', 'fancybox': True, 'shadow': True}

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 100, 501)
y = np.sin(x)

legend_dict = dict(ncol=1, loc='best', fancybox=True, shadow=True)
label = 'xy data sample'
#label = None

plt.plot(x, y, label=label) 
plt.legend(**legend_dict)
plt.show()

# %%
import pandas as pd
import matplotlib

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
matplotlib.__version__
# Out:
# '3.9.0'
