# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from kitikiplot import KitikiPlot
import pandas as pd

df= pd.read_csv( r"fish_10.csv" )

plot= KitikiPlot( data= df)#[i for i in "A T G C A T G C A A A".split()], window_length= 5, stride= 1)

# %%
plot.plot(figsize= (20, 5), display_legend= True,
          cmap="PuBuGn",
          kitiki_cell_kwargs= {"linestyle": "-"},
           legend_kwargs= {"bbox_to_anchor": (1.05, 1), "loc":'upper left', "borderaxespad": 0.},
             xticks_rotation= 45,
             transpose= True,
             cell_width=2
             )

# %%
plot.plot(figsize= (10, 5), cmap= "rainbow", cell_width= 3, display_hatch= True )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot.plot(figsize= (10, 5), cmap= "rainbow", cell_width= 3, display_hatch= True )
#
# NameError: name 'plot' is not defined

# %%
legend_dict
# Out:
# {'ncol': 1, 'loc': 'best', 'fancybox': True, 'shadow': True}

# %%
import numpy
from typing import VERSION
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 import numpy
# ----> 2 from typing import VERSION
#
# ImportError: cannot import name 'VERSION' from 'typing' (c:\Users\sinch\anaconda3\Lib\typing.py)

# %%
import sys
sys.version
# Out:
# '3.11.4 | packaged by Anaconda, Inc. | (main, Jul  5 2023, 13:47:18) [MSC v.1916 64 bit (AMD64)]'

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 100, 501)
y = np.sin(x)

legend_dict = dict(ncol=1, loc='best', fancybox=True, shadow=True)
label = 'xy data sample'
#label = None

plt.plot(x, y, label=label) 
plt.legend(**legend_dict)
plt.show()

# %%
import pandas as pd
import matplotlib

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
matplotlib.__version__
# Out:
# '3.9.0'
