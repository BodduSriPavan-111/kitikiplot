# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from kitikiplot import KitikiPlot
import pandas as pd

df= pd.read_csv( r"fish_10.csv" )

plot= KitikiPlot( data= df)#[i for i in "A T G C A T G C A A A".split()], window_length= 5, stride= 1)

df.head()
# Out:
#    Whale Whale.1 Whale.2 Whale.3 Whale.4 Whale.5 Whale.6 Shark   Gold  Space
# 0  Whale   Whale   Whale   Whale   Whale   Whale   Shark  Gold   Gold   Gold
# 1  Whale   Whale   Whale   Whale   Whale   Shark    Gold  Gold   Gold   Gold
# 2  Whale   Whale   Whale   Whale   Shark    Gold    Gold  Gold   Gold   Gold
# 3  Whale   Whale   Whale   Shark    Gold    Gold    Gold  Gold   Gold  Shark
# 4  Whale   Whale   Shark    Gold    Gold    Gold    Gold  Gold  Shark  Whale

# %%
plot.plot(figsize= (20, 5), display_legend= True,
          cmap="PuBuGn",
          kitiki_cell_kwargs= {"linestyle": "-"},
           legend_kwargs= {"bbox_to_anchor": (1.05, 1), "loc":'upper left', "borderaxespad": 0.},
             xticks_rotation= 45,
             transpose= False,
             cell_width=2
             )

# %%
[(i+1)*1+(i+1)*2+2/2 for i in range(4)]
# Out:
# [4.0, 7.0, 10.0, 13.0]
